# %%
#created by Sebastian Schmid helpers Gregor Endress
from utils import Dmd, Edmd,load_data_pot_fields
import warnings
warnings.filterwarnings("ignore")

# %%
data = load_data_pot_fields("../potFields/")

# %%
dmd = Dmd(data)
dmd.split_data_in_train_test(130, 30,reduce_faktor=97)
edmd = Edmd(data)
dmd.fit()
dmd.predict()
edmd.split_data_in_train_test(130, 30,reduce_faktor=97)
edmd.fit()
edmd.predict()
print("finish")
# Out:
# [Pipeline] ............... (step 1 of 2) Processing _id, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing dmd, total=   0.1s
# [Pipeline] ............... (step 1 of 2) Processing _id, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing dmd, total=   0.1s
# finish

# %%
dmd.visualize_eigenvalues()
edmd.visualize_eigenvalues()

# %%
dmd.visualize_time_series()
edmd.visualize_time_series()

# %%
dmd.visualize_error_over_time()
edmd.visualize_error_over_time()
